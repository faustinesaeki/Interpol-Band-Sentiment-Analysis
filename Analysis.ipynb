# %% [markdown]
# ## Анализ текста с помощью готовой модели
#
# **Ссылка на модель:** [тык](https://huggingface.co/bhadresh-savani/distilbert-base-uncased-emotion)

# %%
import pandas as pd 
from transformers import pipeline

# %%
model = pipeline("text-classification", 
                 model = 'bhadresh-savani/distilbert-base-uncased-emotion', 
                 return_all_scores = True,
                 device = -1) #cpu
# Out:
# Device set to use cpu
# /home/faust/.local/lib/python3.12/site-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
df = pd.read_json("data/interpol.json")

# %%
def analyze_song(song):
    all_scores = []
    if song is None:
        return pd.Series() #пустой результат

    for section in song:
        try:
            curr_section = ' '.join(section)
            prediction = model(curr_section)[0]  #первый элемент, иначе будет ещё один вложенный список на выходе
            prediction = {i['label'] : i['score'] for i in prediction}

            all_scores.append(prediction)
            print(f"Проанализирована cекция {section[0]}")
        except Exception as e:
            print(f"Ошибка  в {section[0]} : {e}")

    #усредняем результат всех строк для каждой песни
    df_emotions = pd.DataFrame(all_scores).mean()

    return df_emotions

# %%
df_emotions = df['Lyrics Cleaned'].apply(analyze_song)
df = pd.concat([df, df_emotions], axis = 1)
df.head()
# Out:
# Проанализирована cекция Surprise, sometimes, will come around
# Проанализирована cекция I wish I could eat the salt off of your lost faded lips
# Проанализирована cекция But she can read, she can read, she can read, she can read
# Проанализирована cекция But it's different now that I'm poor and aging
# Проанализирована cекция And we can find new ways of living
# Проанализирована cекция But she can read, she can read, she can read, she can read
# Проанализирована cекция It's different now that I'm poor and aging
# Проанализирована cекция It's in the way that she posed
# Проанализирована cекция It's in the way that she walks
# Проанализирована cекция I had seven faces
# Проанализирована cекция But New York cares (Got to be some more change in my life)
# Проанализирована cекция Subway, she is a porno
# Проанализирована cекция It's up to me now, turn on the bright lights
# Проанализирована cекция New York cares (Got to be some more change in my life)
# Проанализирована cекция It's up to me now, turn on the bright lights (got to be some more change in my life)
# Проанализирована cекция Yours is the only version of my desertion
# Проанализирована cекция And you're so cute when you're frustrated, dear
# Проанализирована cекция Sleep tight, grim rite
# Проанализирована cекция You are the only person who's completely certain
# Проанализирована cекция But you cannot safely say that while I will be away
# Проанализирована cекция Sleep tight, grim rite
# Проанализирована cекция Something to say
# Проанализирована cекция I want your silent parts, the parts the birds love
# Проанализирована cекция When I'm feeling lazy, it's probably because
# Проанализирована cекция But each night, I bury my love around you
# Проанализирована cекция This is a concept, this is a bracelet
# Проанализирована cекция This isn't you yet
# Проанализирована cекция Can I get there this way? Yeah, I think so
# Проанализирована cекция We should take a trip now to see new places
# Проанализирована cекция Say hello, say hello to the angels
# Проанализирована cекция Will you put my hands away?
# Проанализирована cекция I'm gonna pull you in close, gonna wrap you up tight
# Проанализирована cекция I feel like love is in the kitchen with a culinary eye
# Проанализирована cекция If you can fix me up, girl, you'll go a long way
# Проанализирована cекция I'll stand by all this drinking if it helps me through these days
# Проанализирована cекция Because friends don't waste wine when there's words to sell
# Проанализирована cекция I'll stand by all this drinking if it helps me through these days
# Проанализирована cекция To break it all away
# Проанализирована cекция This one's called "Stella Was a Diver and She's Always Down"
# Проанализирована cекция When she walks down the street
# Проанализирована cекция But she once fell through the street
# Проанализирована cекция Days
# Проанализирована cекция She was all right 'cause the sea was so airtight, she broke away
# Проанализирована cекция She lies in no place
# Проанализирована cекция At the bottom of the ocean she dwells
# Проанализирована cекция Stella, Stella, oh Stella
# Проанализирована cекция She was all right 'cause the sea was so airtight, she broke away
# Проанализирована cекция Well, she was my catatonic sex toy, love-joy diver
# Проанализирована cекция There's something that's invisible
# Проанализирована cекция Shhhh
# Проанализирована cекция My best friend's a butcher, he has sixteen knives
# Проанализирована cекция He severed segments and secretly liked that
# Проанализирована cекция C'mon now, pussycat
# Проанализирована cекция My best friend's a butcher, he has sixteen knives
# Проанализирована cекция He severed segments and secretly liked that
# Проанализирована cекция Alright
# Проанализирована cекция I wish I could live free
# Проанализирована cекция I gave a lot to you
# Проанализирована cекция But I can't pretend I need to defend
# Проанализирована cекция You're looking alright tonight
# Проанализирована cекция She says it helps with the lights out
# Проанализирована cекция The clock is set for nine but you know you're gonna make it eight
# Проанализирована cекция She feels that my sentimental side should be held with kids' gloves
# Проанализирована cекция The clock is set for nine but you know you're gonna make it eight
# Проанализирована cекция I'll bring you when my lifeboat sails through the night
# Проанализирована cекция She says brief things, her love's a pony
# Проанализирована cекция We ain't goin' to the town
# Проанализирована cекция Goin'
# Проанализирована cекция So, baby, make it with me in preparation for tonight
# Проанализирована cекция Goin'
# Проанализирована cекция We ain't goin' to the town
# Проанализирована cекция Rosemary
# Проанализирована cекция Hey, wait
# Проанализирована cекция It took a lifespan with no cellmate
# Проанализирована cекция We speaks about travel
# Проанализирована cекция Hey, wait
# Проанализирована cекция It took a lifespan with no cellmate
# Проанализирована cекция Leave some shards under the belly
# Проанализирована cекция I spent a lifespan with no cellmate
# Проанализирована cекция Touch your thighs, I'm the lonely one
# Проанализирована cекция Baby, you can see that the gazing eye won't lie
# Проанализирована cекция She found a lonely sound
# Проанализирована cекция Feast your eyes, I'm the only one
# Проанализирована cекция But, baby, you can see that the gazing eye won't lie
# Проанализирована cекция She found a lonely sound
# Проанализирована cекция We slips into the bedroom
# Проанализирована cекция You should be in my space
# Проанализирована cекция I'm timeless is like a broken watch
# Проанализирована cекция Baby, don't you try to find me
# Проанализирована cекция Along the way, tears drown in the wake of delight
# Проанализирована cекция I am the scavenger between the sheets of union
# Проанализирована cекция Lady, don't you try to find me
# Проанализирована cекция We sail today, tears will drown in your wake of delight
# Проанализирована cекция White Goddess
# Проанализирована cекция Yeah, but nobody searches
# Проанализирована cекция Can't you see what you've done to my heart and soul?
# Проанализирована cекция We spies, we slow hands
# Проанализирована cекция I submit, my incentive is romanced
# Проанализирована cекция Can't you see what you've done to my heart and soul?
# Проанализирована cекция We spies, yeah, we slow hands
# Проанализирована cекция We spies, we slow hands
# Проанализирована cекция I'll lay down my glasses
# Проанализирована cекция I'll say it now
# Проанализирована cекция When personality is scarred tissue
# Проанализирована cекция We marshal in the days of longing
# Проанализирована cекция Oh, but hold it still, darling, your hair so pretty
# Проанализирована cекция I pretend like no one else
# Проанализирована cекция If time is my vessel, then learning to love
# Проанализирована cекция We all get paid
# Проанализирована cекция How many days will it take to land?
# Проанализирована cекция Oh, so swoon, baby, starry nights
# Проанализирована cекция There is love to be made
# Проанализирована cекция How many days will it take to land?
# Проанализирована cекция So swoon, baby, starry nights
# Проанализирована cекция Swoon, baby, starry nights
# Проанализирована cекция It's way too late
# Проанализирована cекция Sacred parts
# Проанализирована cекция And so may
# Проанализирована cекция Set the date
# Проанализирована cекция And so may
# Проанализирована cекция Now seasoned with health
# Проанализирована cекция Oh, how I love you
# Проанализирована cекция And so may
# Проанализирована cекция Now seasoned with health
# Проанализирована cекция This could be destiny
# Проанализирована cекция Combat salacious removal
# Проанализирована cекция There is a bitter breed
# Проанализирована cекция Combat salacious removal
# Проанализирована cекция Combat salacious removal
# Проанализирована cекция We saw you from the urchin's side, from under the boat
# Проанализирована cекция He whistles and he runs
# Проанализирована cекция We saw you in distraction, a sleeping, slow despair
# Проанализирована cекция He whistles and he runs, so hold him fast
# Проанализирована cекция When the cadaverous mob saves its doors for the dead men
# Проанализирована cекция Lurching and lurching, now you're looking for your friends
# Проанализирована cекция Show me the dirt pile and I will pray that the soul can take
# Проанализирована cекция Well, it's still pretty what with all these leaks, we'll be fine
# Проанализирована cекция You show me the dirt pile and I will pray that the soul can take
# Проанализирована cекция I know you try
# Проанализирована cекция So much for make-believe, I'm not sold
# Проанализирована cекция Show me the dirt pile and I will pray that the soul can take
# Проанализирована cекция Through the storms and the light
# Проанализирована cекция Sound meets sound, babe
# Проанализирована cекция Babe, it's time we give something new a try
# Проанализирована cекция And baby, tonight
# Проанализирована cекция Sound meets sound, babe
# Проанализирована cекция Babe, it's time we give something new a try
# Проанализирована cекция Through the storms and the light
# Проанализирована cекция And I am all for it
# Проанализирована cекция I have a sequin for an eye
# Проанализирована cекция You see that? Well, I made you
# Проанализирована cекция Son, you sleep in clouds of fire
# Проанализирована cекция I can still feel it when you lie
# Проанализирована cекция Under a molten sky
# Проанализирована cекция Son, you sleep in clouds of fire
# Проанализирована cекция How are things on the west coast?
# Проанализирована cекция Today, my heart swings
# Проанализирована cекция How are things on the west coast?
# Проанализирована cекция Today, my heart swings
# Проанализирована cекция Say it
# Проанализирована cекция Let it come
# Проанализирована cекция But today, my heart swings
# Проанализирована cекция Spare me the suspense
# Проанализирована cекция So spare me the suspense
# Проанализирована cекция I won't let you sit by
# Проанализирована cекция Just spare me the suspense
# Проанализирована cекция There are seven ancient pawnshops along the road
# Проанализирована cекция Hey, lady wraith
# Проанализирована cекция But I won’t let you sit by
# Проанализирована cекция Just spare me the suspense
# Проанализирована cекция There are seven ancient pawn shops along the road
# Проанализирована cекция Wait, oh, you froze in the night
# Проанализирована cекция And you wait till you know that it's time
# Проанализирована cекция You can't hold it too tight
# Проанализирована cекция I've seen love
# Проанализирована cекция Yeah, pace is the trick
# Проанализирована cекция Well I see you as you take your pride, my lioness
# Проанализирована cекция I've seen love
# Проанализирована cекция And now I select you, slow now I let you
# Проанализирована cекция And to all the destruction in man
# Проанализирована cекция And now I select you, slow now I let you
# Проанализирована cекция You don't hold a candle
# Проанализирована cекция I dream of you draped in wires and leaning on the brakes
# Проанализирована cекция I'll take you on
# Проанализирована cекция I haven't struck you with desire
# Проанализирована cекция See, I got this soul
# Проанализирована cекция I teach you of Death's desires reflected in lakes
# Проанализирована cекция I'll take you on
# Проанализирована cекция I haven't struck you with desire
# Проанализирована cекция See, I've got this soul
# Проанализирована cекция You're all mine
# Проанализирована cекция I haven't slept for two days
# Проанализирована cекция Tonight I'm gonna rest my chemistry
# Проанализирована cекция I live my life filled with no pain
# Проанализирована cекция Tonight I'm gonna rest my chemistry
# Проанализирована cекция But you're so young
# Проанализирована cекция I saw a sign it says "OK"
# Проанализирована cекция Tonight I'm gonna rest my chemistry
# Проанализирована cекция But you're so young
# Проанализирована cекция Tonight I'm gonna rest my chemistry
# Проанализирована cекция Slow decay, I won't stop fighting yet
# Проанализирована cекция Can it be true?
# Проанализирована cекция Nobody warned you, nobody told you
# Проанализирована cекция Strange and fine, all this hardware (Don't wait)
# Проанализирована cекция Nobody warned you, nobody told you
# Проанализирована cекция Strange and fine, all this hardware (Don't wait)
# Проанализирована cекция Edisni m'I
# Проанализирована cекция This place is set to break
# Проанализирована cекция And I want that
# Проанализирована cекция What do the waves have to say now? (Oh, now I'm free)
# Проанализирована cекция And I want that
# Проанализирована cекция Dreams of long life
# Проанализирована cекция Good eye
# Проанализирована cекция Dreams of long life
# Проанализирована cекция Was a good try
# Проанализирована cекция As high as the day
# Проанализирована cекция I have succeeded
# Проанализирована cекция Dreams of long life
# Проанализирована cекция Somebody make me say no, no
# Проанализирована cекция I have succeeded (yeah)
# Проанализирована cекция I'm not supposed to show you
# Проанализирована cекция It would be so nice to take you
# Проанализирована cекция It would be no price to pay
# Проанализирована cекция Tonight, a special memory serves me
# Проанализирована cекция It's over, it's over
# Проанализирована cекция Tonight, a special memory serves me
# Проанализирована cекция And I forget why we'll say
# Проанализирована cекция It would be no price to pay
# Проанализирована cекция You don't have to say that you'd love to
# Проанализирована cекция The fevered plastics that seal your body
# Проанализирована cекция I want to stay magical
# Проанализирована cекция All the while all the protests that shined the same
# Проанализирована cекция It's alright
# Проанализирована cекция I miss you, babe
# Проанализирована cекция The rainy days
# Проанализирована cекция You know we have ways
# Проанализирована cекция All the while all the protests that shined the same
# Проанализирована cекция It's alright
# Проанализирована cекция All that I see
# Проанализирована cекция All that I fear
# Проанализирована cекция Estuary won't you take me
# Проанализирована cекция All that I seek
# Проанализирована cекция How have you been, my day
# Проанализирована cекция All that I feel
# Проанализирована cекция All that I can see
# Проанализирована cекция No heart unseen will be left so clean
# Проанализирована cекция All that I see
# Проанализирована cекция We'd like to take the sights (That's why I hold you)
# Проанализирована cекция That's why I hold you
# Проанализирована cекция I did not take to analysis
# Проанализирована cекция Bees and snakes need homes (need homes)
# Проанализирована cекция It starts to feel like a barricade
# Проанализирована cекция I could not lean on the politics
# Проанализирована cекция Bees and snakes need homes (need homes)
# Проанализирована cекция It starts to feel like a barricade
# Проанализирована cекция Full speed, half blind
# Проанализирована cекция Sometimes it feels like a barricade
# Проанализирована cекция Full speed, half blind
# Проанализирована cекция Full speed, half blind
# Проанализирована cекция Always you need me lover
# Проанализирована cекция I'm not the hero out the gate
# Проанализирована cекция I am safe without it
# Проанализирована cекция Go alone, we'll split the chase
# Проанализирована cекция I am safe without it
# Проанализирована cекция But I feel this way
# Проанализирована cекция I need the sunlight, to keep me above
# Проанализирована cекция On this side, you wanna see that
# Проанализирована cекция Please explore my love's endurance
# Проанализирована cекция On this side, you wanna see that
# Проанализирована cекция Try it on
# Проанализирована cекция On this side, you're gonna see that
# Проанализирована cекция There's nowhere to stay, there's nowhere to stay
# Проанализирована cекция Tell me you're mine
# Проанализирована cекция This twee neophyte
# Проанализирована cекция All of the ways you will make it up
# Проанализирована cекция Tell me you'll fight
# Проанализирована cекция All of the ways you will make it up
# Проанализирована cекция All of the ways you will make it up
# Проанализирована cекция I was on my way
# Проанализирована cекция I was chased, thrilled and altered
# Проанализирована cекция It usually has
# Проанализирована cекция I always thought you had great style, great style
# Проанализирована cекция Chasing my damage (chasing)
# Проанализирована cекция It usually has (please)
# Проанализирована cекция Please, please the place we're in now (all night long)
# Проанализирована cекция When she went, "hey love come over"
# Проанализирована cекция She said you don't need time
# Проанализирована cекция I keep falling, maybe half the time, maybe half the time
# Проанализирована cекция When she said, "love, come over"
# Проанализирована cекция She said, "you oughtta refine"
# Проанализирована cекция I keep falling, maybe half the time, maybe half the time
# Проанализирована cекция All the rage back home
# Проанализирована cекция Be my desire
# Проанализирована cекция Feel my desire
# Проанализирована cекция Come on baby
# Проанализирована cекция See my desire
# Проанализирована cекция Come on baby
# Проанализирована cекция I've been there
# Проанализирована cекция Be my desire
# Проанализирована cекция Come on baby
# Проанализирована cекция I've been there
# Проанализирована cекция We try to invade
# Проанализирована cекция See the ocean
# Проанализирована cекция You know all about me
# Проанализирована cекция We try to engage
# Проанализирована cекция See the ocean
# Проанализирована cекция You know all about me
# Проанализирована cекция See the ocean
# Проанализирована cекция Same town, new story
# Проанализирована cекция So I bet she stood by him
# Проанализирована cекция She said it feels like the whole world
# Проанализирована cекция How many bombs went off?
# Проанализирована cекция So I bet she stood by him to the law
# Проанализирована cекция Feels like the whole world
# Проанализирована cекция Wide eyed, venture so slowly
# Проанализирована cекция Fade out
# Проанализирована cекция When love comes, honey, take it
# Проанализирована cекция There's someone that I'm dying to be
# Проанализирована cекция Fade
# Проанализирована cекция There's someone that I'm dying to be
# Проанализирована cекция Just say it in the way you go by
# Проанализирована cекция When love comes, honey, show it
# Проанализирована cекция Cruising in my blue Supreme
# Проанализирована cекция (Truly, truly, truly)
# Проанализирована cекция Enter the override, how we run the day
# Проанализирована cекция Everything is wrong, wrong, everything is wrong
# Проанализирована cекция I think I know why I say what I say
# Проанализирована cекция Everything is wrong, wrong, everything is wrong
# Проанализирована cекция Oh love, hold on, hold on, hold on
# Проанализирована cекция We made our home without begging your pardon
# Проанализирована cекция Come back, come back, I'm the warning
# Проанализирована cекция You seen the way
# Проанализирована cекция Come back, come back, I'm the warning
# Проанализирована cекция You see the way how it happens, right
# Проанализирована cекция And I feel my deep makeup
# Проанализирована cекция Come back, come back, I'm the warning
# Проанализирована cекция Day's begun
# Проанализирована cекция And I've seen my deep makeup
# Проанализирована cекция Come back, come back, I'm the warning
# Проанализирована cекция Ooh, fuck the ancient ways
# Проанализирована cекция Ooh, got the time, won't seek
# Проанализирована cекция The city feeds us all like babes
# Проанализирована cекция Ooh, shape the fight through sound
# Проанализирована cекция Ooh, fuck the ancient ways
# Проанализирована cекция The city needs us and all our names
# Проанализирована cекция The city sees us all like babes
# Проанализирована cекция Should we seek them for the sake of it?
# Проанализирована cекция Day by day
# Проанализирована cекция Oh, what a sweet serenade
# Проанализирована cекция Last Friday
# Проанализирована cекция Oh, what a sweet Saturday
# Проанализирована cекция Tidal wave
# Проанализирована cекция Oh, there's a flood coming soon
# Проанализирована cекция Tidal wave
# Проанализирована cекция There were days of no surprise on the wing
# Проанализирована cекция If these times should signify my mistakes
# Проанализирована cекция Twice as hard
# Проанализирована cекция I relied on fewer lies to let you in
# Проанализирована cекция Twice as hard
# Проанализирована cекция All those nights of many lights fall away
# Проанализирована cекция Twice as hard
# Проанализирована cекция Twice as hard
# Проанализирована cекция If you really love nothing
# Проанализирована cекция When I find my home
# Проанализирована cекция If you really love nothing
# Проанализирована cекция When I find my home
# Проанализирована cекция Breathe in, it’s optimal
# Проанализирована cекция When I find my home
# Проанализирована cекция You can trace a hole upon your dress
# Проанализирована cекция Come and see me and maybe you'll die
# Проанализирована cекция Come and see me, yeah, maybe you'll try
# Проанализирована cекция "Walk in on your own feet"
# Проанализирована cекция Ça suffit, hell yeah, maybe it's time
# Проанализирована cекция "Walk in on your own feet"
# Проанализирована cекция Come and see me, yeah baby, let's cry
# Проанализирована cекция "Walk in on your own feet"
# Проанализирована cекция Said "Hop in, all in"
# Проанализирована cекция I dream of complications
# Проанализирована cекция What’ll it be
# Проанализирована cекция Ties me up again
# Проанализирована cекция Dream of combinations
# Проанализирована cекция Oh, what’ll it be
# Проанализирована cекция Ties me up again
# Проанализирована cекция Sidling up the street
# Проанализирована cекция Dream of complications
# Проанализирована cекция Who reigns in that silence
# Проанализирована cекция This was made for me
# Проанализирована cекция You reach out to freedom
# Проанализирована cекция This was made for me
# Проанализирована cекция I came to see you in starlight
# Проанализирована cекция Leave my head to spin
# Проанализирована cекция When we first met you were love tied
# Проанализирована cекция Leave my head to spin
# Проанализирована cекция That's how you lose
# Проанализирована cекция None
# Проанализирована cекция Mountain child
# Проанализирована cекция Are you out of your head?
# Проанализирована cекция Mountain child
# Проанализирована cекция Are you out of your head?
# Проанализирована cекция Show me what it is
# Проанализирована cекция Hero
# Проанализирована cекция Like Prince sang in Tennessee
# Проанализирована cекция Sinking in
# Проанализирована cекция Give me the oversight inside the other
# Проанализирована cекция And with these inclinations
# Проанализирована cекция Swooping in
# Проанализирована cекция Give me the oversight inside the other
# Проанализирована cекция Is it safe, are we far for the mountains?
# Проанализирована cекция Give me the oversight inside the other
# Проанализирована cекция Now you’ve seen me at work
# Проанализирована cекция Surveillance, we’ve seen it all again
# Проанализирована cекция This shit is made up
# Проанализирована cекция Surveillance
# Проанализирована cекция Be famous, but still technically fine
# Проанализирована cекция This shit is made up
# Проанализирована cекция Surveillance, we’ve seen it all again
# Проанализирована cекция Dangerous ingrained in us
# Проанализирована cекция We are living something frame by frame
# Проанализирована cекция Your secret’s safe here, it’ll never leave
# Проанализирована cекция Ella
# Проанализирована cекция Your secret’s safe here, it’ll never leave
# Проанализирована cекция Ella
# Проанализирована cекция Don’t need replacement
# Проанализирована cекция I can see you on internet
# Проанализирована cекция These enhance my bad intentions
# Проанализирована cекция Let them come crash it
# Проанализирована cекция Rock 'n' roll bitch, I’m into it
# Проанализирована cекция Leading hand keeps the distance
# Проанализирована cекция Let them come crash it
# Проанализирована cекция There was some great neighbors who found me
# Проанализирована cекция Let them come crash it
# Проанализирована cекция And so it ends, and so it ends, I'm going in
# Проанализирована cекция None
# Проанализирована cекция I tried to be a faithful man
# Проанализирована cекция It probably matters
# Проанализирована cекция When did you ever hesitate to be mine
# Проанализирована cекция It probably matters
# Проанализирована cекция I need answers
# Проанализирована cекция How many hours I gave for this
# Проанализирована cекция Flame down Pacific highway
# Проанализирована cекция I'd like to see them win
# Проанализирована cекция The aim now is perfection always
# Проанализирована cекция I'd like to see them win
# Проанализирована cекция Who are you to doubt it?
# Проанализирована cекция You're truly erupting too hard
# Проанализирована cекция It's time we made something stable
# Проанализирована cекция I'll do it over again
# Проанализирована cекция It's time we made something stable (something)
# Проанализирована cекция Come on baby, it was a pleasure to know
# Проанализирована cекция I do it all for the glow
# Проанализирована cекция It's time we made something stable (something)
# Проанализирована cекция Come on baby, it was a pleasure to know
# Проанализирована cекция Step around, don't stand there waiting
# Проанализирована cекция Only when the clouds will know me
# Проанализирована cекция Step it down no separating
# Проанализирована cекция Only when the clouds will know me
# Проанализирована cекция Our leaves in the darkness
# Проанализирована cекция Fate came down on me
# Проанализирована cекция Only then the clouds will know me
# Проанализирована cекция Our leaves in the darkness
# Проанализирована cекция Evening snowflake, time had to go late
# Проанализирована cекция There's nothing left to stop it
# Проанализирована cекция I wanna be there when you touch fire
# Проанализирована cекция I had a dream
# Проанализирована cекция I wanna be therе when you touch fire
# Проанализирована cекция I saw you when you gave me chase
# Проанализирована cекция I'll be the hand to lift you up higher
# Проанализирована cекция I waded through shame for this
# Проанализирована cекция I waded through shame for this
# Проанализирована cекция I got a numb skull
# Проанализирована cекция Something changed, we're out gunning
# Проанализирована cекция I want to see
# Проанализирована cекция I don't like these open endings
# Проанализирована cекция I got a numb skull
# Проанализирована cекция Something changed, and I'm out gunning
# Проанализирована cекция I wanna see
# Проанализирована cекция I forgive you but there's no pretending (It becomes automatic, it becomes all but free)
# Проанализирована cекция Something changed, we're out gunning
# Проанализирована cекция And I wanna see
# Проанализирована cекция It becomes automatic, it becomes all but free
# Проанализирована cекция Draw me a million years
# Проанализирована cекция The serpent spins
# Проанализирована cекция Call me from any age
# Проанализирована cекция The serpent spins
# Проанализирована cекция No, no, no
# Проанализирована cекция Out on the wind we go
# Проанализирована cекция The serpent spins
# Проанализирована cекция Roll up the window
# Проанализирована cекция Met a girl then
# Проанализирована cекция I'm on the other side of make-believe
# Проанализирована cекция Free from these fables, we can grow
# Проанализирована cекция There's nothing so sacred, I ain't tried to chase it
# Проанализирована cекция Hey now
# Проанализирована cекция Save me, I'm in my head
# Проанализирована cекция There's nothing so sacred, I ain't tried to chase it
# Проанализирована cекция Hey now
# Проанализирована cекция Save me, I'm in my head
# Проанализирована cекция Kept along, I got nothing but my own dreams
# Проанализирована cекция It's alright to be, not to behave
# Проанализирована cекция Stepped along, now my troubles got their own themes
# Проанализирована cекция It's alright to be, not to behave
# Проанализирована cекция It's out there, it's really out there
# Проанализирована cекция It's alright to be, not to behave
# Проанализирована cекция It's out there, it's really out there
# Проанализирована cекция On the streets of Cozumel where my age is slow
# Проанализирована cекция So close I'm taking notes on my brain
# Проанализирована cекция On the streets of Cozumel where my age is slow
# Проанализирована cекция All that we've got to be is candid and gentle, to be certified
# Проанализирована cекция I see you in everything
# Проанализирована cекция Stop the operation
# Проанализирована cекция (Believe)
# Проанализирована cекция Big shot city losing vibrations over me
# Проанализирована cекция (Believe)
# Проанализирована cекция Big shot city
# Проанализирована cекция Big shot city losing vibrations over me
# Проанализирована cекция Did we know that was halcyon?
# Проанализирована cекция Go easy
# Проанализирована cекция I felt fated for so long
# Проанализирована cекция Go easy
# Проанализирована cекция I'll keep pushing it forward
# Проанализирована cекция At the yard sale
# Проанализирована cекция Come on, go easy
#      Artist                 Album Name               Track Name Key  Tempo  \
# 0  Interpol  Turn On the Bright Lights                 Untitled  Ab     92
# 1  Interpol  Turn On the Bright Lights               Obstacle 1   F    121
# 2  Interpol  Turn On the Bright Lights                      NYC   F    149
# 3  Interpol  Turn On the Bright Lights                      PDA  F#    138
# 4  Interpol  Turn On the Bright Lights  Say Hello to the Angels   A    103
#
#      Mode                                     Lyrics Cleaned   sadness  \
# 0   Major  [[Surprise, sometimes, will come around, Surpr...  0.004170
# 1   Major  [[I wish I could eat the salt off of your lost...  0.628548
# 2   Major  [[I had seven faces, Thought I knew which one ...  0.024825
# 3   Minor  [[Yours is the only version of my desertion, T...  0.178159
# 4   Minor  [[I want your silent parts, the parts the bird...  0.212803
#
#         joy      love     anger      fear  surprise
# 0  0.457357  0.002486  0.008452  0.022101  0.505434
# 1  0.258516  0.002606  0.106197  0.003179  0.000955
# 2  0.498694  0.012795  0.240601  0.008274  0.214810
# 3  0.325133  0.006691  0.430700  0.057378  0.001939
# 4  0.400630  0.112457  0.251379  0.020475  0.002257

# %%
gloom_df = df.sort_values(by="sadness", ascending=False)

gloom_df
# Out:
#       Artist                      Album Name       Track Name Key  Tempo  \
# 1   Interpol       Turn On the Bright Lights       Obstacle 1   F    121
# 67  Interpol  The Other Side Of Make-Believe   Into the Night   C    136
# 10  Interpol       Turn On the Bright Lights     Leif Erikson   G    109
# 46  Interpol                       El Pintor  My Blue Supreme   C    103
# 55  Interpol                        Marauder  Flight of Fancy   C    133
# ..       ...                             ...              ...  ..    ...
# 19  Interpol                          Antics   Length of Love  Bb    127
# 16  Interpol                          Antics    Not Even Jail   C    125
# 8   Interpol       Turn On the Bright Lights           Roland   E    146
# 0   Interpol       Turn On the Bright Lights         Untitled  Ab     92
# 72  Interpol  The Other Side Of Make-Believe        Greenwich   G    141
#
#       Mode                                     Lyrics Cleaned   sadness  \
# 1    Major  [[I wish I could eat the salt off of your lost...  0.628548
# 67   Major  [[Step around, don't stand there waiting, On a...  0.536693
# 10   Major  [[She says it helps with the lights out, Her r...  0.483146
# 46   Major  [[Fade out, You've already made a scene around...  0.444619
# 55   Major  [[Who reigns in that silence, When you sleep i...  0.417772
# ..     ...                                                ...       ...
# 19   Major  [[This could be destiny, Oh, sweetheart, I've ...  0.008505
# 16   Minor  [[I'll lay down my glasses, I'll lay down in h...  0.007692
# 8    Minor  [[Shhhh, C'mon, c'mon, Hey], [My best friend's...  0.006880
# 0    Major  [[Surprise, sometimes, will come around, Surpr...  0.004170
# 72   Major  [[Kept along, I got nothing but my own dreams,...  0.002732
#
#          joy      love     anger      fear  surprise
# 1   0.258516  0.002606  0.106197  0.003179  0.000955
# 67  0.216694  0.031524  0.175091  0.039094  0.000904
# 10  0.187726  0.147521  0.176763  0.004355  0.000489
# 46  0.410290  0.004952  0.134042  0.005180  0.000916
# 55  0.473934  0.004231  0.090228  0.001896  0.011940
# ..       ...       ...       ...       ...       ...
# 19  0.712618  0.023246  0.252549  0.002125  0.000957
# 16  0.334249  0.211688  0.112321  0.333095  0.000954
# 8   0.164443  0.259693  0.291485  0.275603  0.001896
# 0   0.457357  0.002486  0.008452  0.022101  0.505434
# 72  0.843327  0.001005  0.150370  0.002174  0.000392
#
# [76 rows x 13 columns]

# %%
df.to_json('data/interpol_analyzed_lyrics.json')

# %% [markdown]
# ## Тональность + Темп
# **Важно:** при выборе примерного числового значения для каждого сочетания я ориентировалась на информацию [отсюда](https://legacy.wmich.edu/mus-theo/courses/keys.html), чтобы получить общие представления об аккордах. Выводы очень субъективные.

# %%
df = pd.read_json('data/interpol_analyzed_lyrics.json')
df['Mode'] = df['Mode'].apply(str.strip)
df['Key'] = df['Key'].apply(str.strip)
print(df.value_counts(['Key', 'Mode']))
# Out:
# Key  Mode
# G    Major    11
# C    Major    10
# B    Minor     8
# E    Minor     7
# A    Minor     7
# D    Major     5
#      Minor     5
# F#   Minor     4
# F    Major     4
# Ab   Major     3
# Bb   Major     3
# A    Major     2
# C    Minor     2
# E    Major     1
# F    Minor     1
# B    Major     1
# Ab   Minor     1
# G    Minor     1
# Name: count, dtype: int64

# %%
#пропущенные значения это D минор, всё, вроде, нормально? По количеству совпадает
#типо, при выборе key == None он НИЧЕГО НЕ НАХОДИТ
missing_key = df[(df['Key'] == 'D') & (df['Mode']== 'Minor')]
print(missing_key[['Track Name', 'Album Name']])
# Out:
#                Track Name          Album Name
# 18                 C'mere              Antics
# 20  A Time to Be So Small              Antics
# 26      Pace Is the Trick  Our Love to Admire
# 31         The Lighthouse  Our Love to Admire
# 64    It Probably Matters            Marauder

# %%
key_values = {
    'Bb Minor': {'sadness': 0.4, 'joy': -0.5, 'anger': 0.2, 'fear': 0.3},
    'Ab Minor': {'sadness': 0.38, 'joy': -0.48, 'anger': 0.15, 'fear': 0.25},
    'D Minor': {'sadness': 0.35, 'joy': -0.5, 'love': 0.1, 'anger': 0.15},
    'F Minor': {'sadness': 0.35, 'joy': -0.45},
    'G Minor': {'sadness': 0.3, 'joy': -0.45, 'anger': 0.2, 'fear': 0.2},
    'C Minor': {'sadness': 0.3, 'joy': -0.45, 'love': 0.2},
    'B Minor': {'sadness': 0.4, 'joy': -0.35},
    'F# Minor': {'sadness': 0.35, 'joy': -0.4, 'anger': 0.1, 'fear': 0.1},
    'A Minor': {'sadness': 0.2, 'joy': -0.4, 'love': 0.2, 'fear': 0.1},
    'E Minor': {'sadness': 0.25, 'joy': -0.4, 'love': 0.3},
    'G# Minor': {'sadness': 0.25, 'joy': -0.3, 'fear': 0.1},

    'Ab Major': {'sadness': 0.05, 'joy': 0.1, 'love': 0.15},
    'Bb Major': {'sadness': 0.0, 'joy': 0.1, 'love': 0.05},
    'C Major': {'sadness': -0.1, 'joy': 0.1},
    'A Major': {'sadness': 0.1, 'joy': 0.1, 'love': 0.1},
    'F Major': {'sadness': -0.1, 'joy': 0.15, 'love': 0.1},
    'G Major': {'sadness': 0.1, 'joy': 0.15, 'love': 0.1},
    'D Major': {'sadness': -0.05, 'joy': 0.2, 'love': 0.15},
    'E Major': {'sadness': -0.05, 'joy': 0.25, 'love': 0.2},
    'B Major': {'sadness': -0.1, 'joy': 0.3, 'love': 0.1},
}

emotions = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']

# %%
def apply_key_emotions(song, emotions = emotions, key_values = key_values):
    key_and_mode = f"{song["Key"]} {song["Mode"]}"

    if key_and_mode in key_values:
        emotions_adjusted = song[emotions].copy() #копия, чтобы не менять пока исходный дф

        #применение весов
        for emotion, weight in key_values[key_and_mode].items():
            if emotion in emotions_adjusted.index:
                emotions_adjusted[emotion] += weight
        return emotions_adjusted
    
    else:
        return song[emotions]

# %%
def apply_bpm_emotions(song):
    bpm = song['Tempo']
    emotions_adjusted = song[emotions].copy() #копия, чтобы не менять пока исходный дф
    
    effects = {'sadness': 0, 'joy': 0,
               'anger': 0, 'fear': 0}
    
    if bpm <= 65:
        effects.update({'sadness': 0.4, 'fear': 0.3, 'joy': -0.3})
    elif 66 <= bpm <= 80:
        effects.update({'sadness': 0.3, 'fear': 0.2, 'joy' : -0.25})
    elif 81 <= bpm <= 100:
        effects.update({'sadness': 0.2, 'anger': 0.1, 'joy' : -0.15})
    elif 101 <= bpm <= 120:
        effects.update({'sadness': 0.1, 'joy': -0.1, 'anger': 0.15})
    elif 121 <= bpm <= 140:
        effects.update({'anger': 0.2, 'fear': 0.1, 'joy': -0.05, 'sadness' : 0.1})
    elif bpm >= 141:
        effects.update({'anger': 0.25, 'fear': 0.25, 'joy': -0.1})
    
    for emotion, weight in effects.items():
        if emotion in emotions_adjusted:
            emotions_adjusted[emotion] += weight
            
    return emotions_adjusted

# %%
def normalize_emotions (song):
    emotions_values = song[emotions].copy()
    
    total = emotions_values.sum()

    if total > 0:
        normalized = emotions_values / total
    else:
        #если cумма 0, распределяем поровну
        normalized = pd.Series([1/len(emotions)] * len(emotions), index=emotions)
    return normalized

# %%
def apply_all(song):
    result = song[emotions].copy()
    
    #копия песни с новыми значениями
    temp_song = song.copy()
    temp_song[emotions] = result
    
    result = apply_key_emotions(temp_song)
    temp_song[emotions] = result
    
    result = apply_bpm_emotions(temp_song)
    temp_song[emotions] = result

    result = normalize_emotions(temp_song)
    return result

# %%
df = pd.read_json('data/interpol_analyzed_lyrics.json')

df[emotions] = df.apply(apply_all, axis = 1)

df.sort_values(by='sadness', ascending=False)
# Out:
#       Artist                      Album Name  \
# 7   Interpol       Turn On the Bright Lights
# 40  Interpol                        Interpol
# 1   Interpol       Turn On the Bright Lights
# 69  Interpol  The Other Side Of Make-Believe
# 20  Interpol                          Antics
# ..       ...                             ...
# 39  Interpol                        Interpol
# 75  Interpol  The Other Side Of Make-Believe
# 58  Interpol                        Marauder
# 51  Interpol                       El Pintor
# 2   Interpol       Turn On the Bright Lights
#
#                                     Track Name Key  Tempo    Mode  \
# 7   Stella Was a Diver and She Was Always Down   F    114   Minor
# 40                             All of the Ways   B     79   Minor
# 1                                   Obstacle 1   F    121   Major
# 69                           Something Changed   C    120   Minor
# 20                       A Time to Be So Small   D     87   Minor
# ..                                         ...  ..    ...     ...
# 39                                   Try It On   C    132   Major
# 75                           Go Easy (Palermo)   C    108   Major
# 58                              Mountain Child   C    129   Major
# 51                               Twice as Hard   D    165   Major
# 2                                          NYC   F    149   Major
#
#                                        Lyrics Cleaned   sadness       joy  \
# 7   [[This one's called "Stella Was a Diver and Sh...  0.667846 -0.440322
# 40  [[Tell me you're mine, Baby, tell me you're mi...  0.563211 -0.038509
# 1   [[I wish I could eat the salt off of your lost...  0.539665  0.154456
# 69  [[I waded through shame for this], [I waded th...  0.531581 -0.064308
# 20  [[We saw you from the urchin's side, from unde...  0.526166 -0.339854
# ..                                                ...       ...       ...
# 39  [[I need the sunlight, to keep me above, These...  0.024219  0.370365
# 75  [[Go easy, Go easy, Go easy, Go easy, Don't ma...  0.019548  0.480513
# 58  [[Mountain child, You're up in the trees like ...  0.006703  0.168732
# 51  [[There were days of no surprise on the wing, ... -0.006724  0.214364
# 2   [[I had seven faces, Thought I knew which one ... -0.048500  0.353996
#
#         love     anger      fear  surprise
# 7   0.170793  0.321842  0.277053  0.002788
# 40  0.005016  0.303941  0.164985  0.001357
# 1   0.001931  0.226813  0.076429  0.000707
# 69  0.169813  0.355747  0.006169  0.000998
# 20  0.081830  0.599692  0.130073  0.002093
# ..       ...       ...       ...       ...
# 39  0.013295  0.503679  0.087089  0.001353
# 75  0.004612  0.485515  0.008600  0.001212
# 58  0.001223  0.601164  0.153710  0.068468
# 51  0.093097  0.548175  0.150379  0.000708
# 2   0.072771  0.316517  0.166629  0.138587
#
# [76 rows x 13 columns]

# %% [markdown]
# ## Обложки альбомов

# %%
album_covers = {"Turn On the Bright Lights" : "https://lastfm.freetls.fastly.net/i/u/3fe8c6984be61796f337afd7d58e921a",
                "Antics" : "https://lastfm.freetls.fastly.net/i/u/dbedf82b014c45faad56d5a34609091c",
                "Our Love to Admire" : "https://lastfm.freetls.fastly.net/i/u/15d2aa8a66d448358eef9e933a8c0a17",
                "Interpol" : "https://lastfm.freetls.fastly.net/i/u/17e545b4a2af43dc80e6b91f87f2827f",
                "El Pintor" : "https://lastfm.freetls.fastly.net/i/u/65d6575f771343c6c3a4139efb1bfdf3", 
                "Marauder" : "https://lastfm.freetls.fastly.net/i/u/49bf393f7cb6f8f86ca4fe6f797d5edf",
                "The Other Side Of Make-Believe" : "https://lastfm.freetls.fastly.net/i/u/32624d570e74625844267de63586a990"
                }

df['Album Cover'] = df['Album Name'].map(album_covers)
df.head()
# Out:
#      Artist                 Album Name               Track Name Key  Tempo  \
# 0  Interpol  Turn On the Bright Lights                 Untitled  Ab     92
# 1  Interpol  Turn On the Bright Lights               Obstacle 1   F    121
# 2  Interpol  Turn On the Bright Lights                      NYC   F    149
# 3  Interpol  Turn On the Bright Lights                      PDA  F#    138
# 4  Interpol  Turn On the Bright Lights  Say Hello to the Angels   A    103
#
#      Mode                                     Lyrics Cleaned   sadness  \
# 0   Major  [[Surprise, sometimes, will come around, Surpr...  0.175290
# 1   Major  [[I wish I could eat the salt off of your lost...  0.539665
# 2   Major  [[I had seven faces, Thought I knew which one ... -0.048500
# 3   Minor  [[Yours is the only version of my desertion, T...  0.418772
# 4   Minor  [[I want your silent parts, the parts the bird...  0.410242
#
#         joy      love     anger      fear  surprise  \
# 0  0.280936  0.105163  0.074794  0.015242  0.348575
# 1  0.154456  0.001931  0.226813  0.076429  0.000707
# 2  0.353996  0.072771  0.316517  0.166629  0.138587
# 3 -0.083245  0.004461  0.487134  0.171585  0.001293
# 4 -0.079496  0.249965  0.321103  0.096380  0.001806
#
#                                          Album Cover
# 0  https://lastfm.freetls.fastly.net/i/u/3fe8c698...
# 1  https://lastfm.freetls.fastly.net/i/u/3fe8c698...
# 2  https://lastfm.freetls.fastly.net/i/u/3fe8c698...
# 3  https://lastfm.freetls.fastly.net/i/u/3fe8c698...
# 4  https://lastfm.freetls.fastly.net/i/u/3fe8c698...

# %% [markdown]
# ## Мрачность (Gloom Score)

# %%
def gloom_score(song):
    weights = {
        'sadness': 0.7,
        'joy': -0.25,
        'anger': 0.2,
        'fear': 0.25,
        'surprise': 0.15,
        'love': -0.3}
    
    weighted_sum = sum(song[emotion] * weight for emotion, weight in weights.items())
    
    total_weight = sum(abs(weight) for weight in weights.values())
    
    normalized_score = (weighted_sum + total_weight) / (2 * total_weight)
    
    #0 или 1, если есть выбросы
    return max(0, min(1, normalized_score))

# %%
df['Gloom'] = df.apply(gloom_score, axis = 1)
df.sort_values(by ='Gloom', ascending=False)
# Out:
#       Artist                      Album Name  \
# 7   Interpol       Turn On the Bright Lights
# 68  Interpol  The Other Side Of Make-Believe
# 20  Interpol                          Antics
# 9   Interpol       Turn On the Bright Lights
# 40  Interpol                        Interpol
# ..       ...                             ...
# 19  Interpol                          Antics
# 2   Interpol       Turn On the Bright Lights
# 72  Interpol  The Other Side Of Make-Believe
# 14  Interpol                          Antics
# 6   Interpol       Turn On the Bright Lights
#
#                                     Track Name Key  Tempo   Mode  \
# 7   Stella Was a Diver and She Was Always Down   F    114  Minor
# 68                                   Mr.Credit  F#     74  Minor
# 20                       A Time to Be So Small   D     87  Minor
# 9                                      The New   G    113  Minor
# 40                             All of the Ways   B     79  Minor
# ..                                         ...  ..    ...    ...
# 19                              Length of Love  Bb    127  Major
# 2                                          NYC   F    149  Major
# 72                                   Greenwich   G    141  Major
# 14                        Take You on a Cruise   D    118  Major
# 6                                   Obstacle 2   D    116  Major
#
#                                        Lyrics Cleaned   sadness       joy  \
# 7   [[This one's called "Stella Was a Diver and Sh...  0.667846 -0.440322
# 68  [[There's nothing left to stop it, How long we...  0.503453 -0.380557
# 20  [[We saw you from the urchin's side, from unde...  0.526166 -0.339854
# 9   [[I wish I could live free, I hope it's not be...  0.443321 -0.175208
# 40  [[Tell me you're mine, Baby, tell me you're mi...  0.563211 -0.038509
# ..                                                ...       ...       ...
# 19  [[This could be destiny, Oh, sweetheart, I've ...  0.072337  0.508412
# 2   [[I had seven faces, Thought I knew which one ... -0.048500  0.353996
# 72  [[Kept along, I got nothing but my own dreams,...  0.058704  0.510472
# 14  [[I'm timeless is like a broken watch, I make ...  0.080143  0.486066
# 6   [[I'm gonna pull you in close, gonna wrap you ...  0.075026  0.576618
#
#         love     anger      fear  surprise  \
# 7   0.170793  0.321842  0.277053  0.002788
# 68  0.007601  0.566524  0.301787  0.001193
# 20  0.081830  0.599692  0.130073  0.002093
# 9   0.003281  0.582278  0.145778  0.000551
# 40  0.005016  0.303941  0.164985  0.001357
# ..       ...       ...       ...       ...
# 19  0.048831  0.301700  0.068083  0.000638
# 2   0.072771  0.316517  0.166629  0.138587
# 72  0.057717  0.228783  0.144100  0.000224
# 14  0.113381  0.312189  0.007725  0.000495
# 6   0.105503  0.233568  0.007941  0.001344
#
#                                           Album Cover     Gloom
# 7   https://lastfm.freetls.fastly.net/i/u/3fe8c698...  0.678482
# 68  https://lastfm.freetls.fastly.net/i/u/32624d57...  0.671407
# 20  https://lastfm.freetls.fastly.net/i/u/dbedf82b...  0.657163
# 9   https://lastfm.freetls.fastly.net/i/u/3fe8c698...  0.636791
# 40  https://lastfm.freetls.fastly.net/i/u/17e545b4...  0.636381
# ..                                                ...       ...
# 19  https://lastfm.freetls.fastly.net/i/u/dbedf82b...  0.496308
# 2   https://lastfm.freetls.fastly.net/i/u/3fe8c698...  0.494991
# 72  https://lastfm.freetls.fastly.net/i/u/32624d57...  0.494047
# 14  https://lastfm.freetls.fastly.net/i/u/dbedf82b...  0.490544
# 6   https://lastfm.freetls.fastly.net/i/u/3fe8c698...  0.479895
#
# [76 rows x 15 columns]

# %%
df.to_json('data/interpol_complete.json')
